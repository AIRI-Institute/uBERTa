# %% [markdown]
# # Modeling using XGBoost
#
# Here, we'll train the `XGBoostClassifier` and make predictions for the 5'UTR sequences.
#
# **NOTE**: due to different data preparation routines, this notebook may require more RAM than uBERTa notebooks.
# For this reason, we may run chunks of the cells: e.g, prepare data first, then restart, then run training.
# This will break the numeration order.
#
#
# ## Packages
#
# **NOTE**: this notebook purpesfully doesn't depend on the uBERTa's source code, and has different dependencies. If running from the uBERTa environment, please install additionally the following packages:
#
# - scikit-learn
# - optuna
# - joblib
# - xgboost
#
#
# ## Data prerequisites
#
# - [DS_BASE](https://drive.google.com/file/d/15fQP5ldYNvV1YY2T2Qza9CNFdYj4zZg8/view?usp=sharing) (`../data/DS_BASE_v4.7_seqs.tsv`)
# - [dataset_labeling](https://drive.google.com/file/d/1-R1zLJRrJg3KXAaqDe9T60s9MXdrv4RO/view?usp=sharing) (`../data/dataset_labeling_v.4.7.tsv`)
# - [expression_data](https://drive.google.com/file/d/1AsrwNL5rsmnQoI6Mw1XdYlT4MUtZLNOZ/view?usp=sharing) (`../data/rna_single_cell_type.tsv.zip`)
#
# One can either download or obtain the requirements manually using `prepare_base_dataset.ipynb`. The expression data can be downloaded either from [proteinatlas.org](https://www.proteinatlas.org/about/download) or using the link above.
#
# For instance, starting from the project's root:
# ```bash
# gdown --fuzzy https://drive.google.com/file/d/15fQP5ldYNvV1YY2T2Qza9CNFdYj4zZg8/view?usp=sharing
# gdown --fuzzy https://drive.google.com/file/d/1-R1zLJRrJg3KXAaqDe9T60s9MXdrv4RO/view?usp=sharing
# gdown --fuzzy https://drive.google.com/file/d/1AsrwNL5rsmnQoI6Mw1XdYlT4MUtZLNOZ/view?usp=sharing
# tar -xzf DS_BASE_v4.7_seqs.tsv.tar.gz
# tar -xzf dataset_labeling_v4.7.tsv.tar.gz
# ```

# %%
import operator as op
from collections import namedtuple
from itertools import chain
from pathlib import Path

import joblib
import numpy as np
import optuna
import pandas as pd
from more_itertools import chunked, unzip, sliding_window
from sklearn.metrics import f1_score, precision_score, recall_score, roc_auc_score, balanced_accuracy_score
from tqdm.auto import tqdm
from xgboost import XGBClassifier

# %%
DATA_ = Path('../data')
DS = DATA_ / 'DS_BASE_v4.7_seqs.tsv'
DS_LABELS = DATA_ / 'dataset_labeling_v4.7.tsv'
RNA_CELL = DATA_ / 'rna_single_cell_type.tsv.zip'

RNA_SIDE = 50  # Flank sizes around start codons
SIG_SIDE = 50

MIN_SEQ_SIZE = 30
MAX_SEQ_SIZE = 3000

STARTS = ('AAG', 'ACG', 'AGG', 'ATA', 'ATC', 'ATG', 'ATT', 'CTG', 'GTG', 'TTG')
np.random.seed(666)

# %%
# ref = Ref(BASE / 'hg38.fa')

# %%
# logging.basicConfig(level=logging.DEBUG)

# %%
DATA = DATA_ / 'XGB'
DATA.mkdir(exist_ok=True)

DATA_PATHS = {
    'base_inp': DS,
    'labels_inp': DS_LABELS,
    'rna_cell_inp': RNA_CELL,

    'base_prep': DATA / 'base_centered.tsv',
    'meta': DATA / 'metadata.csv',
    'signal': DATA / 'signal.csv',
    'seq_rna': DATA / 'seq_rna.csv',
    'seq_raw': DATA / 'seq_raw.csv',
    'idx': DATA / 'idx.joblib',
    'labels': DATA / 'labels.csv',
    'rna_cell': DATA / 'rna_cell.csv',
    'train_x': DATA / 'train_x.csv',
    'train_y': DATA / 'train_y.csv',
    'val_x': DATA / 'val_x.csv',
    'val_y': DATA / 'val_y.csv',
    'test_x': DATA / 'test_x.csv',
    'test_y': DATA / 'test_y.csv',
    'cv': DATA / 'cv_predictions.csv',
}

# %%
XY = namedtuple('xy', ['x', 'y'])


def split_values(
        df: pd.DataFrame, col: str, to_array: bool = True,
        dtype=np.int, sep=',', conv_to=None) -> pd.DataFrame:
    def split(vs):
        if not isinstance(vs, str):
            return vs
        _vs = vs.split(sep)
        if conv_to:
            _vs = list(map(conv_to, _vs))
        if to_array:
            _vs = np.array(_vs, dtype=dtype)
        return _vs

    df[col] = df[col].apply(split)
    return df


def parse_base(path_base, min_seq_size, max_seq_size):
    df = pd.read_csv(path_base, sep='\t')
    df['SeqSize'] = df['Seq'].apply(len)
    print(f'Initial ds: {len(df)}')
    df = df[(df.SeqSize >= min_seq_size) & (df.SeqSize <= max_seq_size)]
    print(f'Conforming to size threshold: {len(df)}')
    split_values(df, 'SeqEnum')
    split_values(df, 'Classes')
    split_values(df, 'Signal', dtype=float)
    return df


def pad_and_slice_around(a, idx, side, **kwargs):
    assert idx < len(a), 'index lower than array size'
    assert idx >= 0, 'index at least 0'
    size_l = side - len(a[max([0, idx - side]):idx])
    size_r = side - len(a[idx + 1: idx + side + 1])

    a_pad = np.pad(a, (size_l, size_r), **kwargs)

    idx_new = idx + size_l

    return a_pad[idx_new - side: idx_new + side + 1]


def center_ds(df: pd.DataFrame):
    def unravel(row):
        mask = row.Classes != -100
        seq = list(row['Seq'])
        sig = row['Signal']

        prepend_values = [row[c] for c in cols_prepend]
        for idx in np.where(mask)[0]:
            pos = row['SeqEnum'][idx]
            cls = row['Classes'][idx]
            seq_c = pad_and_slice_around(seq, idx, RNA_SIDE, constant_values='X')
            seq_c = ''.join(seq_c)
            sig_c = pad_and_slice_around(sig, idx, SIG_SIDE, constant_values=0.0)
            sig_c = ','.join(map(str, sig_c))
            start = ''.join(seq_c[RNA_SIDE: RNA_SIDE + 3])
            yield *prepend_values, seq_c, start, cls, pos, sig_c

    cols_roll = ['Seq', 'Start', 'Classes', 'SeqEnum', 'Signal']
    cols_prepend = [c for c in df.columns if c not in cols_roll]
    columns = cols_prepend + cols_roll

    rows = tqdm(df.iterrows(), total=len(df), desc='Unraveling')

    unraveled = chain.from_iterable(map(unravel, map(op.itemgetter(1), rows)))

    return pd.DataFrame(unraveled, columns=columns)


def encode_one_hot(df, feature_range, col='Seq', prefix='', chars='ACGT', missing='XN'):
    feature_names = list(chain.from_iterable(
        (f'{prefix}{x}_{c}' for c in chars) for x in feature_range))
    mapping = {c: x for c, x in zip(chars, np.eye(len(chars), dtype=int))}
    zero = np.zeros(len(chars), dtype=int)
    mapping.update({c: zero for c in missing})
    encode = lambda s: np.hstack([mapping[c] for c in s])
    xs = np.vstack(df[col].map(encode).values)
    return pd.DataFrame(xs, columns=feature_names)


def scale(x, a, b):
    min_x = np.min(x)
    max_x = np.max(x)
    return a + (b - a) * (x - min_x) / (max_x - min_x)


def centered_range(l):
    mid = l // 2
    return range(-mid, mid + 1)


def prep_rna(df):
    l = len(df.iloc[0]['Seq'])
    return encode_one_hot(df, centered_range(l), 'Seq', 'r_')


def prep_signal(
        x_sig, cap_max: float = 5000.0, scale_min: float = 0.0, scale_max: float = 10.0
) -> pd.DataFrame:
    x_sig[x_sig >= cap_max] = cap_max
    x_sig = scale(x_sig, scale_min, scale_max)
    columns = [f's_{i}' for i in centered_range(x_sig.shape[1])]
    return pd.DataFrame(x_sig, columns=columns)


def standardize(x):
    return (x - np.mean(x)) / np.std(x)


def prep_atlas_data(df, path, columns, idx_name='Gene', val_name='nTPM', val_transform=standardize):
    df_atlas = pd.read_csv(path, sep='\t')
    if val_transform is not None:
        df_atlas[val_name] = val_transform(df_atlas[val_name])
    df_atlas = df_atlas.pivot_table(
        index=idx_name, columns=columns, values=val_name
    ).reset_index().rename(columns={'Gene': 'GeneID'})

    return df[['GeneID']].merge(
        df_atlas, on='GeneID', how='left'
    ).fillna(0.0).drop(columns='GeneID')


def load_chunks(size, datasets):

    chunks = (
        pd.read_csv(DATA_PATHS[n], chunksize=size) for n in 
        ['rna_cell', 'signal', 'seq_rna', 'labels', 'meta'])
    bar = tqdm(desc='Loading chunks')
    
    for i, (cell_chunk, signal_chunk, seq_chunk, ys_chunk, meta_chunk) in enumerate(zip(*chunks), start=1):
        bar.update(1)
        idx = meta_chunk['Dataset'].isin(datasets)
        if idx.sum():
            ds_x = pd.concat([signal_chunk[idx], seq_chunk[idx], cell_chunk[idx]], axis=1)
            meta_chunk = meta_chunk[idx].copy()
            meta_chunk['y_true'] = ys_chunk.loc[idx, 'Classes'].values
            yield ds_x, meta_chunk
    bar.close()

def compute_scores(y_pred, y):
    return {
        'f1': f1_score(y, y_pred, zero_division=0),
        'prc': precision_score(y, y_pred, zero_division=0),
        'rec': recall_score(y, y_pred, zero_division=0),
        'bac': balanced_accuracy_score(y, y_pred)
    }

# %% [markdown]
# ## Prepare centered dataset
#
# - As explained in the accompanying paper, the dataset preparation routines differs from distilBERT. Namely, we'll create the "centered" dataset, where each valid start-codon in 5'UTR transcript sequences is used as anchor around which the flanking sequences and . As a result, the features and positions are the same for each instance. Furthermore, the sequences themselves are one-hot encoded, while the ribo-seq signal is prepared in the same manner as for uBERTa.

# %%
ds = parse_base(DS, MIN_SEQ_SIZE, MAX_SEQ_SIZE).drop(
    columns=['SeqSize']
)
# Out:
# Initial ds: 79453
# Conforming to size threshold: 73797

# %% [markdown]
# - Create k-merized sequences. The padding is added to match the shape of the sequence-level features and won't be used further.

# %%
ds['SeqKmers'] = ds['Seq'].apply(
    lambda x: np.array([''.join(y) for y in sliding_window(x, 3)] + ['PAD', 'PAD']))

# %% [markdown]
# - Create masks based on classes' labeling and apply it to sequence-level features to obtain classes' and positions for valid start codons.

# %%
ds['ClsIdx'] = [np.where(x != -100)[0] for x in ds['Classes']]
for col in ['SeqKmers', 'Classes', 'SeqEnum']:
    ds[col] = [x[i] for i, x in zip(ds['ClsIdx'], ds[col])]

# %% [markdown]
# - Explore the dataset based on masked sequence-level features.

# %%
ds = ds.explode(['SeqKmers', 'Classes', 'SeqEnum', 'ClsIdx'])

# %%
ds = ds[~ds['ClsIdx'].isna()].copy()

# %%
ds.SeqKmers.value_counts()
# Out:
# CTG    511620
# AGG    432923
# AAG    326845
# GTG    324174
# TTG    254256
# ATT    190227
# ATC    170906
# ATG    167271
# ACG    124085
# ATA    111804
# Name: SeqKmers, dtype: int64

# %% [markdown]
# - Label dataset for each valid codon based on GeneID

# %%
labels = pd.read_csv(DS_LABELS, sep='\t')
ds = ds.merge(labels, on='GeneID', how='left')

# %% [markdown]
# - Slice and pad sequences and signal around the start codon position

# %%
ds['Seq'] = [
    ''.join(pad_and_slice_around(list(s), i, RNA_SIDE, constant_values='X'))
    for i, s in tqdm(ds[['ClsIdx', 'Seq']].itertuples(index=False), total=len(ds))]
# Out:
#   0%|          | 0/2614111 [00:00<?, ?it/s]

# %%
ds['Signal'] = [
    pad_and_slice_around(list(s), i, SIG_SIDE, constant_values=0.0)
    for i, s in tqdm(ds[['ClsIdx', 'Signal']].itertuples(index=False), total=len(ds))]
# Out:
#   0%|          | 0/2614111 [00:00<?, ?it/s]

# %%
len(ds)
# Out:
# 2614111

# %% [markdown]
# - Drop sequences for which using different transcripts did not result in changing the sequence around the start codon position

# %%
ds = ds.drop_duplicates(['Seq', 'SeqEnum', 'Chrom', 'Strand', 'Dataset'])

# %%
len(ds)
# Out:
# 1858737

# %%
ds = ds.rename(columns={'SeqKmers': 'Start'})

# %% [markdown]
# - We'll dump classes as a separate table for convenience

# %%
ds[['Classes']].to_csv(DATA_PATHS['labels'], index=False)

# %% [markdown]
# - Stack all experimental signals into a single matrix and transform it by capping at 5000 and linearly scaling between 0 and 10.

# %%
signals = np.vstack([x for x in ds['Signal']])
prep_signal(signals).to_csv(DATA_PATHS['signal'], index=False)

# %%
del signals

# %%
with DATA_PATHS['seq_raw'].open('w') as f:
    print('Seq', file=f)
    for s in tqdm(ds['Seq'], total=len(ds)):
        print(s, file=f)
# Out:
#   0%|          | 0/1858737 [00:00<?, ?it/s]

# %% [markdown]
# - Dump metadata that we'll use later for predictions and validation

# %%
ds[
    ['GeneID', 'TranscriptID', 'Chrom', 'Strand', 
     'SeqEnum', 'Start', 'Dataset']
].to_csv(DATA_PATHS['meta'], index=False)

# %% [markdown]
# ## Prep sequences
#
# - Here, we'll restart the notebook and run only the fist 7 cells.
# - Then we'll encode each sequence using one-hot approach

# %%
df_seq = pd.read_csv(DATA_PATHS['seq_raw'])

# %%
prep_rna(df_seq).to_csv(DATA_PATHS['seq_rna'], index=False)

# %% [markdown]
# ## Prep gene-level features
#
# - Per-cell expression levels standardized and merged on GeneID

# %%
meta = pd.read_csv(DATA_PATHS['meta'])

# %%
prep_atlas_data(
    meta, DATA_PATHS['rna_cell_inp'], ['Cell type']
).round(5).to_csv(DATA_PATHS['rna_cell'], index=False)

# %%
# prep_atlas_data(
#     ds, DATA_PATHS['rna_tissue_inp'], ['Tissue']
# ).to_csv(DATA_PATHS['rna_tissue'], index=False)

# %% [markdown]
# ## Prep xy
#
# - Merge the data into a single table. We'll load the data using sizeable chunks and save the training/testing/validation folds.

# %%
for ds in tqdm(['Train', 'Val', 'Test']):
    xs, ms = map(pd.concat, unzip(load_chunks(50000, [ds])))
    ys = ms[['y_true']]
    name = ds.lower()
    xs.to_csv(DATA_PATHS[f'{name}_x'], index=False)
    ys.to_csv(DATA_PATHS[f'{name}_y'], index=False)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Loading chunks: 0it [00:00, ?it/s]
# Loading chunks: 0it [00:00, ?it/s]
# Loading chunks: 0it [00:00, ?it/s]

# %% [markdown]
# ## Optimize params

# %%
train = XY(
    pd.read_csv(DATA_PATHS['train_x']), 
    pd.read_csv(DATA_PATHS['train_y']))
val = XY(
    pd.read_csv(DATA_PATHS['val_x']), 
    pd.read_csv(DATA_PATHS['val_y']))

# %%
def objective(trial, train=train, val=val):
    params = {
        'grow_policy': trial.suggest_categorical('grow_policy', ['lossguide']),
        'learning_rate': trial.suggest_float('learning_rate', 1e-2, 2),
        'max_depth': trial.suggest_int('max_depth', 4, 20),
        'gamma': trial.suggest_float('gamma', 1e-2, 2.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 20.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 20.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.1, 1.0),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1.0, 20.0),
    }
    model = XGBClassifier(
        **params, objective='binary:logistic', tree_method='gpu_hist',
        gpu_id='1',
        early_stopping_rounds=10, n_jobs=-1)
    model.fit(
        train.x.values, train.y.values,
        eval_set=[(val.x.values, val.y.values)],
        verbose=False)
    y_pred = model.predict(val.x)
    score = f1_score(val.y, y_pred)
    return score

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2022-10-19 10:13:04,657] A new study created in memory with name: no-name-47795dca-c848-4088-aa95-a934b40086e8
# [I 2022-10-19 10:13:15,593] Trial 0 finished with value: 0.5859065716547902 and parameters: {'grow_policy': 'lossguide', 'learning_rate': 1.4333147796033734, 'max_depth': 16, 'gamma': 1.456887486756961, 'reg_lambda': 4.343441428512205, 'reg_alpha': 18.87490044289007, 'colsample_bytree': 0.5930214226127545, 'colsample_bylevel': 0.43924726554219595, 'scale_pos_weight': 19.240142988514062}. Best is trial 0 with value: 0.5859065716547902.
# [I 2022-10-19 10:13:22,449] Trial 1 finished with value: 0.585209003215434 and parameters: {'grow_policy': 'lossguide', 'learning_rate': 1.6081560824429457, 'max_depth': 10, 'gamma': 1.2661162484795707, 'reg_lambda': 18.725049515380377, 'reg_alpha': 0.8034072764836298, 'colsample_bytree': 0.6737178419831429, 'colsample_bylevel': 0.58996071887815, 'scale_pos_weight': 17.720787826200667}. Best is trial 0 with value: 0.5859065716547902.
# [I 2022-10-19 10:13:31,231] Trial 2 finished with value: 0.6510538641686182 and parameters: {'grow_policy': 'lossguide', 'learning_rate': 0.7771149543405184, 'max_depth': 5, 'gamma': 0.4740605047662789, 'reg_lambda': 6.488030400199259, 'reg_alpha': 4.541007546358111, 'colsample_bytree': 0.7759096650798376, 'colsample_bylevel': 0.6810222394392883, 'scale_pos_weight': 17.314217836572702}. Best is trial 2 with value: 0.6510538641686182.
# [I 2022-10-19 10:13:42,163] Trial 3 finished with value: 0.6470085470085469 and parameters: {'grow_policy': 'lossguide', 'learning_rate': 0
. Best is trial 43 with value: 0.6970633693972178.
# [I 2022-10-19 10:29:19,227] Trial 94 finished with value: 0.6728820429671666 and parameters: {'grow_policy': 'lossguide', 'learning_rate': 0.273963496873886, 'max_depth': 7, 'gamma': 1.3810295714769147, 'reg_lambda': 1.058312892688986, 'reg_alpha': 16.129137016344938, 'colsample_bytree': 0.5746426806032449, 'colsample_bylevel': 0.8144815089362002, 'scale_pos_weight': 7.147690764739346}. Best is trial 43 with value: 0.6970633693972178.
# [I 2022-10-19 10:29:30,542] Trial 95 finished with value: 0.6714399363564041 and parameters: {'grow_policy': 'lossguide', 'learning_rate': 0.31276590948958677, 'max_depth': 10, 'gamma': 1.5538856220519173, 'reg_lambda': 1.672349011649748, 'reg_alpha': 17.186875921686916, 'colsample_bytree': 0.9213858929455623, 'colsample_bylevel': 0.8658341278040923, 'scale_pos_weight': 9.902339470784293}. Best is trial 43 with value: 0.6970633693972178.
# [I 2022-10-19 10:29:39,525] Trial 96 finished with value: 0.6733824099186362 and parameters: {'grow_policy': 'lossguide', 'learning_rate': 0.4492647578748038, 'max_depth': 7, 'gamma': 1.1174257772141472, 'reg_lambda': 0.3355739672795004, 'reg_alpha': 13.487021409597416, 'colsample_bytree': 0.6399624158258083, 'colsample_bylevel': 0.7875033828452928, 'scale_pos_weight': 11.925613703750248}. Best is trial 43 with value: 0.6970633693972178.
# [I 2022-10-19 10:29:52,256] Trial 97 finished with value: 0.6984011627906977 and parameters: {'grow_policy': 'lossguide', 'learning_rate': 0.09936924483593312, 'max_depth': 8, 'gamma': 1.477343705723823, 'reg_lambda': 2.2045941577676516, 'reg_alpha': 17.903008925728273, 'colsample_bytree': 0.5943715796308908, 'colsample_bylevel': 0.7329001180439547, 'scale_pos_weight': 10.655241464899479}. Best is trial 97 with value: 0.6984011627906977.
# [I 2022-10-19 10:30:06,655] Trial 98 finished with value: 0.69558599695586 and parameters: {'grow_policy': 'lossguide', 'learning_rate': 0.09800087705758045, 'max_depth': 9, 'gamma': 1.483983673198943, 'reg_lambda': 3.378524823192832, 'reg_alpha': 17.67200308174063, 'colsample_bytree': 0.5611381040602407, 'colsample_bylevel': 0.720616908692038, 'scale_pos_weight': 11.431272338510594}. Best is trial 97 with value: 0.6984011627906977.
# [I 2022-10-19 10:30:22,293] Trial 99 finished with value: 0.6917466410748561 and parameters: {'grow_policy': 'lossguide', 'learning_rate': 0.10197988520663154, 'max_depth': 10, 'gamma': 1.485292379852946, 'reg_lambda': 3.395518996212166, 'reg_alpha': 17.734392345017042, 'colsample_bytree': 0.5186835096009993, 'colsample_bylevel': 0.7200749892045597, 'scale_pos_weight': 11.33223749982911}. Best is trial 97 with value: 0.6984011627906977.

# %%
study.best_params
# Out:
# {'grow_policy': 'lossguide',
#  'learning_rate': 0.09936924483593312,
#  'max_depth': 8,
#  'gamma': 1.477343705723823,
#  'reg_lambda': 2.2045941577676516,
#  'reg_alpha': 17.903008925728273,
#  'colsample_bytree': 0.5943715796308908,
#  'colsample_bylevel': 0.7329001180439547,
#  'scale_pos_weight': 10.655241464899479}

# %% [markdown]
# ## Cross-validate

# %%
def generate_fold_idx(df: pd.DataFrame, on: str = 'GeneID', frac: float = 0.1):
    vs = df[on].unique()
    np.random.shuffle(vs)
    chunk_size = int(len(vs) * frac)
    chunks = list(chunked(vs, chunk_size, strict=False))
    for i in range(len(chunks)):
        test_vs = chunks[i]
        train_vs = np.concatenate(
            [chunks[j] for j in range(len(chunks)) if i != j])
        yield df[on].isin(train_vs).values, df[on].isin(test_vs).values


def fit_and_predict(train_x, train_y, idx_train, idx_test, i_fold, metadata, params, frac=0.1):

    train_fold_x, train_fold_y = train_x[idx_train], train_y[idx_train]
    test_fold_x, test_fold_y = train_x[idx_test], train_y[idx_test]

    idx_eval = np.random.binomial(1, frac, len(train_fold_x)).astype(bool)

    train_sub_x, train_sub_y = train_fold_x[idx_eval], train_fold_y[idx_eval]
    eval_sub_x, eval_sub_y = train_fold_x[~idx_eval], train_fold_y[~idx_eval]

    classifier = XGBClassifier(**params)
    classifier.fit(train_sub_x, train_sub_y, eval_set=[(eval_sub_x, eval_sub_y)])
    y_prob = classifier.predict_proba(test_fold_x)
    metadata.loc[idx_test, 'fold'] = i_fold
    metadata.loc[idx_test, 'y_prob'] = y_prob[:, 1]

# %%
best_params = {
    'grow_policy': 'lossguide',
    'learning_rate': 0.09936924483593312,
    'max_depth': 8,
    'gamma': 1.477343705723823,
    'reg_lambda': 2.2045941577676516,
    'reg_alpha': 17.903008925728273,
    'colsample_bytree': 0.5943715796308908,
    'colsample_bylevel': 0.7329001180439547,
    'scale_pos_weight': 10.655241464899479,
    'n_estimators': 10000,
    'tree_method': 'gpu_hist',
    'early_stopping_rounds': 10,
    'gpu_id': '1'
}

# %%
xs, meta = map(pd.concat, unzip(load_chunks(100000, ['Train', 'Val'])))
ys = meta[['y_true']]
# Out:
# Loading chunks: 0it [00:00, ?it/s]

# %%
for i, (idx_train, idx_test) in tqdm(
    enumerate(generate_fold_idx(meta), start=1), desc='Fitting models', total=10
):
    fit_and_predict(xs, ys, idx_train, idx_test, i, meta, best_params)
# Out:
# Fitting models:   0%|          | 0/10 [00:00<?, ?it/s]
# 356258 39549 35348
# Fitting the model
# [0]	validation_0-logloss:0.61558
# [1]	validation_0-logloss:0.54505
# [2]	validation_0-logloss:0.48637
# [3]	validation_0-logloss:0.43698
# [4]	validation_0-logloss:0.39429
# [5]	validation_0-logloss:0.35759
# [6]	validation_0-logloss:0.32996
# [7]	validation_0-logloss:0.30146
# [8]	validation_0-logloss:0.27869
# [9]	validation_0-logloss:0.25651
# [10]	validation_0-logloss:0.23687
# [11]	validation_0-logloss:0.21923
# [12]	validation_0-logloss:0.20504
# [13]	validation_0-logloss:0.19090
# [14]	validation_0-logloss:0.17834
# [15]	validation_0-logloss:0.16830
# [16]	validation_0-logloss:0.15958
# [17]	validation_0-logloss:0.15019
# [18]	validation_0-logloss:0.14269
# [19]	validation_0-logloss:0.13516
# [20]	validation_0-logloss:0.12913
# [21]	validation_0-logloss:0.12275
# [22]	validation_0-logloss:0.11689
# [23]	validation_0-logloss:0.11168
# [24]	validation_0-logloss:0.10709
# [25]	validation_0-logloss:0.10307
# [26]	validation_0-logloss:0.09919
# [27]	validation_0-logloss:0.09562
# [28]	validation_0-logloss:0.09252
# [29]	validation_0-logloss:0.08969
# [30]	validation_0-logloss:0.08710
# [31]	validation_0-logloss:0.08486
# [32]	validation_0-logloss:0.08288
# [33]	validation_0-logloss:0.08099
# [34]	validation_0-logloss:0.07926
# [35]	validation_0-logloss:0.07738
# [36]	validation_0-logloss:0.07584
# [37]	validation_0-logloss:0.07430
# [38]	validation_0-logloss:0.07295
# [39]	validation_0-logloss:0.07133
# [40]	validation_0-logloss:0.07015
# [41]	validation_0-logloss:0.06891
# [42]	validation_0-logloss:0.06786
# [43]	validation_0-logloss:0.06692
# [44]	validation_0-logloss:0.06610
# [45]	validation_0-logloss:0.06523
# [46]	validation_0-logloss:0.06449
# [47]	validation_0-logloss:0.06370
# [48]	validation_0-logloss:0.06293
# [49]	validation_0-logloss:0.06219
# [50]	validation_0-logloss:0.06164
# [51]	validation_0-logloss:0.06099
# [52]	validation_0-logloss:0.06032
# [53]	validation_0-logloss:0.05973
# [54]	validation_0-logloss:0.05945
# [55]	validation_0-logloss:0.05893
# [56]	validation_0-logloss:0.05848
# [57]	validation_0-logloss:0.05814
# [58]	validation_0-logloss:0.05775
# [59]	validation_0-logloss:0.05741
# [60]	validation_0-logloss:0.05693
# [61]	validation_0-logloss:0.05657
# [62]	validation_0-logloss:0.05629
# [63]	validation_0-logloss:0.05584
# [64]	validation_0-logloss:0.05545
# [65]	validation_0-logloss:0.05517
# [66]	validation_0-logloss:0.05482
# [67]	validation_0-logloss:0.05464
# [68]	validation_0-logloss:0.05434
# [69]	validation_0-logloss:0.05402
# [70]	validation_0-logloss:0.05382
# [71]	validation_0-logloss:0.05360
# [72]	validation_0-logloss:0.05335
# [73]	validation_0-logloss:0.05316
# [74]	validation_0-logloss:0.05300
# [75]	validation_0-logloss:0.05273
# [76]	validation_0-logloss:0.05261
# [77]	validation_0-logloss:0.05239
# [78]	validation_0-logloss:0.05214
# [79]	validation_0-logloss:0.05189
# [80]	validation_0-logloss:0.05169
# [81]	validation_0-logloss:0.05145
# [82]	validation_0-logloss:0.05138
# [83]	validation_0-logloss:0.05130
# [84]	validation_0-logloss:0.05115
# [85]	validation_0-logloss:0.05100
# [86]	validation_0-logloss:0.05083
# [87]	validation_0-logloss:0.05066
# [88]	validation_0-logloss:0.05051
# [89]	validation_0-logloss:0.05034
# [90]	validation_0-logloss:0.05027
# [91]	validation_0-logloss:0.05001
# [92]	validation_0-logloss:0.04979
# [93]	validation_0-logloss:0.04973
# [94]	validation_0-logloss:0.04961
# [95]	validation_0-logloss:0.04943
# [96]	validation_0-logloss:0.04927
# [97]	validation_0-logloss:0.04914
# [98]	validation_0-logloss:0.04894
# [99]	validation_0-logloss:0.04881
# [100]	validation_0-logloss:0.04869
# [101]	validation_0-logloss:0.04873
# [102]	validation_0-logloss:0.04856
# [103]	validation_0-logloss:0.04845
# [104]	validation_0-logloss:0.04834
# [105]	validation_0-logloss:0.04825
# [106]	validation_0-logloss:0.04823
# [107]	validation_0-logloss:0.04818
# [108]	validation_0-logloss:0.04817
# [109]	validation_0-logloss:0.04816
# [110]	validation_0-logloss:0.04801
# [111]	validation_0-logloss:0.04801
# [112]	validation_0-logloss:0.04800
# [113]	validation_0-logloss:0.04800
# [114]	validation_0-logloss:0.04793
# [115]	validation_0-logloss:0.04793
# [116]	validation_0-logloss:0.04793
# [117]	validation_0-logloss:0.04793
# [118]	validation_0-logloss:0.04793
# [119]	validation_0-logloss:0.04793
# [120]	validation_0-logloss:0.04793
# [121]	validation_0-logloss:0.04793
# [122]	validation_0-logloss:0.04793
# [123]	validation_0-logloss:0.04793
# Finished 1
# 357168 38639 35212
# Fitting the model
# [0]	validation_0-logloss:0.61576
# [1]	validation_0-logloss:0.54495
# [2]	validation_0-logloss:0.48615
# [3]	validation_0-logloss:0.43613
# [4]	validation_0-logloss:0.39357
# [5]	validation_0-logloss:0.35676
# [6]	validation_0-logloss:0.32946
# [7]	validation_0-logloss:0.30082
# [8]	validation_0-logloss:0.27827
# [9]	validation_0-logloss:0.25599
# [10]	validation_0-logloss:0.23644
# [11]	validation_0-logloss:0.21888
# [12]	validation_0-logloss:0.20457
# [13]	validation_0-logloss:0.19018
# [14]	validation_0-logloss:0.17777
# [15]	validation_0-logloss:0.16773
# [16]	validation_0-logloss:0.15915
# [17]	validation_0-logloss:0.14975
# [18]	validation_0-logloss:0.14255
# [19]	validation_0-logloss:0.13496
# [20]	validation_0-logloss:0.12874
# [21]	validation_0-logloss:0.12256
# [22]	validation_0-logloss:0.11688
# [23]	validation_0-logloss:0.11180
# [24]	validation_0-logloss:0.10726
# [25]	validation_0-logloss:0.10297
# [26]	validation_0-logloss:0.09907
# [27]	validation_0-logloss:0.09563
# [28]	validation_0-logloss:0.09249
# [29]	validation_0-logloss:0.08955
# [30]	validation_0-logloss:0.08684
# [31]	validation_0-logloss:0.08470
# [32]	validation_0-logloss:0.08286
# [33]	validation_0-logloss:0.08114
# [34]	validation_0-logloss:0.07934
# [35]	validation_0-logloss:0.07756
# [36]	validation_0-logloss:0.07629
# [37]	validation_0-logloss:0.07475
# [38]	validation_0-logloss:0.07343
# [39]	validation_0-logloss:0.07207
# [40]	validation_0-logloss:0.07098
# [41]	validation_0-logloss:0.06996
# [42]	validation_0-logloss:0.06920
# [43]	validation_0-logloss:0.06808
# [44]	validation_0-logloss:0.06730
# [45]	validation_0-logloss:0.06634
# [46]	validation_0-logloss:0.06558
# [47]	validation_0-logloss:0.06474
# [48]	validation_0-logloss:0.06404
# [49]	validation_0-logloss:0.06333
# [50]	validation_0-logloss:0.06289
# [51]	validation_0-logloss:0.06221
# [52]	validation_0-logloss:0.06168
# [53]	validation_0-logloss:0.06113
# [54]	validation_0-logloss:0.06061
# [55]	validation_0-logloss:0.06009
# [56]	validation_0-logloss:0.05972
# [57]	validation_0-logloss:0.05938
# [58]	validation_0-logloss:0.05895
# [59]	validation_0-logloss:0.05865
# [60]	validation_0-logloss:0.05818
# [61]	validation_0-logloss:0.05778
# [62]	validation_0-logloss:0.05745
# [63]	validation_0-logloss:0.05713
# [64]	validation_0-logloss:0.05676
# [65]	validation_0-logloss:0.05645
# [66]	validation_0-logloss:0.05627
# [67]	validation_0-logloss:0.05608
# [68]	validation_0-logloss:0.05579
# [69]	validation_0-logloss:0.05557
# [70]	validation_0-logloss:0.05530
# [71]	validation_0-logloss:0.05496
# [72]	validation_0-logloss:0.05468
# [73]	validation_0-logloss:0.05441
# [74]	validation_0-logloss:0.05417
# [75]	validation_0-logloss:0.05410
# [76]	validation_0-logloss:0.05382
# [77]	validation_0-logloss:0.05354
# [78]	validation_0-logloss:0.05331
# [79]	validation_0-logloss:0.05313
# [80]	validation_0-logloss:0.05298
# [81]	validation_0-logloss:0.05285
# [82]	validation_0-logloss:0.05268
# [83]	validation_0-logloss:0.05250
# [84]	validation_0-logloss:0.05234
# [85]	validation_0-logloss:0.05214
# [86]	validation_0-logloss:0.05191
# [87]	validation_0-logloss:0.05175
# [88]	validation_0-logloss:0.05154
# [89]	validation_0-logloss:0.05138
# [90]	validation_0-logloss:0.05124
# [91]	validation_0-logloss:0.05107
# [92]	validation_0-logloss:0.05089
# [93]	validation_0-logloss:0.05081
# [94]	validation_0-logloss:0.05065
# [95]	validation_0-logloss:0.05050
# [96]	validation_0-logloss:0.05029
# [97]	validation_0-logloss:0.05020
# [98]	validation_0-logloss:0.05000
# [99]	validation_0-logloss:0.04992
# [100]	validation_0-logloss:0.04991
# [101]	validation_0-logloss:0.04977
# [102]	validation_0-logloss:0.04968
# [103]	validation_0-logloss:0.04960
# [104]	validation_0-logloss:0.04953
# [105]	validation_0-logloss:0.04952
# [106]	validation_0-logloss:0.04938
# [107]	validation_0-logloss:0.04933
# [108]	validation_0-logloss:0.04932
# [109]	validation_0-logloss:0.04930
# [110]	validation_0-logloss:0.04921
# [111]	validation_0-logloss:0.04920
# [112]	validation_0-logloss:0.04920
# [113]	validation_0-logloss:0.04920
# [114]	validation_0-logloss:0.04920
# [115]	validation_0-logloss:0.04919
# [116]	validation_0-logloss:0.04919
# [117]	validation_0-logloss:0.04919
# [118]	validation_0-logloss:0.04919
# [119]	validation_0-logloss:0.04919
# [120]	validation_0-logloss:0.04918
# [121]	validation_0-logloss:0.04918
# [122]	validation_0-logloss:0.04918
# [123]	validation_0-logloss:0.04918
# [124]	validation_0-logloss:0.04918
# [125]	validation_0-logloss:0.04918
# [126]	validation_0-logloss:0.04918
# [127]	validation_0-logloss:0.04918
# [128]	validation_0-logloss:0.04918
# [129]	validation_0-logloss:0.04918
# [130]	validation_0-logloss:0.04918
# [131]	validation_0-logloss:0.04918
# [132]	validation_0-logloss:0.04918
# [133]	validation_0-logloss:0.04917
# [134]	validation_0-logloss:0.04917
# [135]	validation_0-logloss:0.04917
# [136]	validation_0-logloss:0.04917
# [137]	validation_0-logloss:0.04917
# [138]	validation_0-logloss:0.04917
# [139]	validation_0-logloss:0.04917
# [140]	validation_0-logloss:0.04917
# [141]	validation_0-logloss:0.04917
# [142]	validation_0-logloss:0.04917
# [143]	validation_0-logloss:0.04917
# [144]	validation_0-logloss:0.04917
# [145]	validation_0-logloss:0.04917
# [146]	validation_0-logloss:0.04917
# [147]	validation_0-logloss:0.04917
# [148]	validation_0-logloss:0.04917
# [846]	validation_0-logloss:0.04726
# [847]	validation_0-logloss:0.04726
# [848]	validation_0-logloss:0.04726
# [849]	validation_0-logloss:0.04726
# [850]	validation_0-logloss:0.04726
# [851]	validation_0-logloss:0.04726
# [852]	validation_0-logloss:0.04726
# [853]	validation_0-logloss:0.04726
# [854]	validation_0-logloss:0.04726
# [855]	validation_0-logloss:0.04726
# [856]	validation_0-logloss:0.04726
# [857]	validation_0-logloss:0.04726
# [858]	validation_0-logloss:0.04726
# [859]	validation_0-logloss:0.04726
# [860]	validation_0-logloss:0.04726
# [861]	validation_0-logloss:0.04726
# [862]	validation_0-logloss:0.04726
# [863]	validation_0-logloss:0.04726
# [864]	validation_0-logloss:0.04726
# [865]	validation_0-logloss:0.04726
# [866]	validation_0-logloss:0.04726
# [867]	validation_0-logloss:0.04726
# [868]	validation_0-logloss:0.04726
# [869]	validation_0-logloss:0.04726
# [870]	validation_0-logloss:0.04726
# [871]	validation_0-logloss:0.04726
# [872]	validation_0-logloss:0.04726
# [873]	validation_0-logloss:0.04726
# [874]	validation_0-logloss:0.04726
# [875]	validation_0-logloss:0.04726
# [876]	validation_0-logloss:0.04726
# [877]	validation_0-logloss:0.04726
# [878]	validation_0-logloss:0.04726
# [879]	validation_0-logloss:0.04726
# [880]	validation_0-logloss:0.04726
# [881]	validation_0-logloss:0.04726
# [882]	validation_0-logloss:0.04726
# [883]	validation_0-logloss:0.04726
# [884]	validation_0-logloss:0.04726
# [885]	validation_0-logloss:0.04726
# [886]	validation_0-logloss:0.04726
# [887]	validation_0-logloss:0.04726
# [888]	validation_0-logloss:0.04726
# [889]	validation_0-logloss:0.04726
# [890]	validation_0-logloss:0.04726
# [891]	validation_0-logloss:0.04726
# [892]	validation_0-logloss:0.04726
# [893]	validation_0-logloss:0.04726
# [894]	validation_0-logloss:0.04726
# [895]	validation_0-logloss:0.04726
# [896]	validation_0-logloss:0.04726
# [897]	validation_0-logloss:0.04726
# [898]	validation_0-logloss:0.04726
# [899]	validation_0-logloss:0.04726
# [900]	validation_0-logloss:0.04726
# [901]	validation_0-logloss:0.04726
# [902]	validation_0-logloss:0.04726
# [903]	validation_0-logloss:0.04726
# [904]	validation_0-logloss:0.04726
# [905]	validation_0-logloss:0.04726
# [906]	validation_0-logloss:0.04726
# [907]	validation_0-logloss:0.04726
# [908]	validation_0-logloss:0.04726
# [909]	validation_0-logloss:0.04726
# [910]	validation_0-logloss:0.04726
# [911]	validation_0-logloss:0.04726
# [912]	validation_0-logloss:0.04726
# [913]	validation_0-logloss:0.04726
# [914]	validation_0-logloss:0.04726
# [915]	validation_0-logloss:0.04726
# [916]	validation_0-logloss:0.04726
# [917]	validation_0-logloss:0.04726
# [918]	validation_0-logloss:0.04726
# [919]	validation_0-logloss:0.04726
# [920]	validation_0-logloss:0.04726
# [921]	validation_0-logloss:0.04726
# [922]	validation_0-logloss:0.04726
# [923]	validation_0-logloss:0.04726
# [924]	validation_0-logloss:0.04726
# [925]	validation_0-logloss:0.04726
# [926]	validation_0-logloss:0.04726
# [927]	validation_0-logloss:0.04726
# [928]	validation_0-logloss:0.04726
# [929]	validation_0-logloss:0.04726
# [930]	validation_0-logloss:0.04726
# [931]	validation_0-logloss:0.04726
# [932]	validation_0-logloss:0.04726
# [933]	validation_0-logloss:0.04726
# [934]	validation_0-logloss:0.04726
# [935]	validation_0-logloss:0.04726
# [936]	validation_0-logloss:0.04726
# [937]	validation_0-logloss:0.04726
# [938]	validation_0-logloss:0.04726
# [939]	validation_0-logloss:0.04726
# [940]	validation_0-logloss:0.04726
# [941]	validation_0-logloss:0.04726
# [942]	validation_0-logloss:0.04726
# [943]	validation_0-logloss:0.04726
# [944]	validation_0-logloss:0.04726
# [945]	validation_0-logloss:0.04726
# [946]	validation_0-logloss:0.04726
# [947]	validation_0-logloss:0.04726
# [948]	validation_0-logloss:0.04726
# [949]	validation_0-logloss:0.04726
# [950]	validation_0-logloss:0.04726
# [951]	validation_0-logloss:0.04726
# [952]	validation_0-logloss:0.04726
# [953]	validation_0-logloss:0.04726
# [954]	validation_0-logloss:0.04726
# [955]	validation_0-logloss:0.04726
# [956]	validation_0-logloss:0.04726
# [957]	validation_0-logloss:0.04726
# [958]	validation_0-logloss:0.04726
# [959]	validation_0-logloss:0.04726
# [960]	validation_0-logloss:0.04726
# [961]	validation_0-logloss:0.04726
# [962]	validation_0-logloss:0.04726
# [963]	validation_0-logloss:0.04726
# [964]	validation_0-logloss:0.04726
# [965]	validation_0-logloss:0.04726
# [966]	validation_0-logloss:0.04726
# [967]	validation_0-logloss:0.04726
# [968]	validation_0-logloss:0.04726
# [969]	validation_0-logloss:0.04726
# [970]	validation_0-logloss:0.04726
# [971]	validation_0-logloss:0.04726
# [972]	validation_0-logloss:0.04726
# [973]	validation_0-logloss:0.04726
# [974]	validation_0-logloss:0.04726
# [975]	validation_0-logloss:0.04726
# [976]	validation_0-logloss:0.04726
# [977]	validation_0-logloss:0.04726
# [978]	validation_0-logloss:0.04726
# [979]	validation_0-logloss:0.04726
# [980]	validation_0-logloss:0.04726
# [981]	validation_0-logloss:0.04726
# [982]	validation_0-logloss:0.04726
# [983]	validation_0-logloss:0.04726
# [984]	validation_0-logloss:0.04726
# [985]	validation_0-logloss:0.04726
# [986]	validation_0-logloss:0.04726
# [987]	validation_0-logloss:0.04726
# [988]	validation_0-logloss:0.04726
# [989]	validation_0-logloss:0.04726
# [990]	validation_0-logloss:0.04726
# [991]	validation_0-logloss:0.04726
# [992]	validation_0-logloss:0.04726
# [993]	validation_0-logloss:0.04726
# [994]	validation_0-logloss:0.04726
# [995]	validation_0-logloss:0.04726
# [996]	validation_0-logloss:0.04726
# [997]	validation_0-logloss:0.04726
# [998]	validation_0-logloss:0.04726
# [999]	validation_0-logloss:0.04726
# [1000]	validation_0-logloss:0.04726
# [1001]	validation_0-logloss:0.04726
# [1002]	validation_0-logloss:0.04726
# [1003]	validation_0-logloss:0.04726
# [1004]	validation_0-logloss:0.04726
# [1005]	validation_0-logloss:0.04726
# [1006]	validation_0-logloss:0.04726
# [1007]	validation_0-logloss:0.04726
# [1008]	validation_0-logloss:0.04726
# [1009]	validation_0-logloss:0.04726
# [1010]	validation_0-logloss:0.04726
# [1011]	validation_0-logloss:0.04726
# [1012]	validation_0-logloss:0.04726
# [1013]	validation_0-logloss:0.04726
# [1014]	validation_0-logloss:0.04726
# [1015]	validation_0-logloss:0.04726
# [1016]	validation_0-logloss:0.04726
# [1017]	validation_0-logloss:0.04726
# [1018]	validation_0-logloss:0.04726
# [1019]	validation_0-logloss:0.04726
# [1020]	validation_0-logloss:0.04726
# [1021]	validation_0-logloss:0.04726
# [1022]	validation_0-logloss:0.04726
# [1023]	validation_0-logloss:0.04726
# [1024]	validation_0-logloss:0.04726
# [1025]	validation_0-logloss:0.04726
# [1026]	validation_0-logloss:0.04726
# [1027]	validation_0-logloss:0.04726
# [1028]	validation_0-logloss:0.04726
# [1029]	validation_0-logloss:0.04726
# [1030]	validation_0-logloss:0.04726
# [1031]	validation_0-logloss:0.04726
# [1032]	validation_0-logloss:0.04726
# [1033]	validation_0-logloss:0.04726
# [1034]	validation_0-logloss:0.04726
# [1035]	validation_0-logloss:0.04726
# [1036]	validation_0-logloss:0.04726
# [1037]	validation_0-logloss:0.04726
# [1038]	validation_0-logloss:0.04726
# [1039]	validation_0-logloss:0.04726
# [1040]	validation_0-logloss:0.04726
# [1041]	validation_0-logloss:0.04726
# [1042]	validation_0-logloss:0.04726
# [1043]	validation_0-logloss:0.04726
# [1044]	validation_0-logloss:0.04726
# [1045]	validation_0-logloss:0.04726
# [1046]	validation_0-logloss:0.04726
# [1047]	validation_0-logloss:0.04726
# [1048]	validation_0-logloss:0.04726
# [1049]	validation_0-logloss:0.04726
# [1050]	validation_0-logloss:0.04726
# [1051]	validation_0-logloss:0.04726
# [1052]	validation_0-logloss:0.04726
# [1053]	validation_0-logloss:0.04726
# [1054]	validation_0-logloss:0.04726
# [1055]	validation_0-logloss:0.04726
# [1056]	validation_0-logloss:0.04726
# [1057]	validation_0-logloss:0.04726
# [1058]	validation_0-logloss:0.04726
# [1059]	validation_0-logloss:0.04726
# [1060]	validation_0-logloss:0.04726
# [1061]	validation_0-logloss:0.04726
# [1062]	validation_0-logloss:0.04726
# [1063]	validation_0-logloss:0.04726
# [1064]	validation_0-logloss:0.04726
# [1065]	validation_0-logloss:0.04726
# [1066]	validation_0-logloss:0.04726
# [1067]	validation_0-logloss:0.04726
# [1068]	validation_0-logloss:0.04726
# [1069]	validation_0-logloss:0.04726
# [1070]	validation_0-logloss:0.04726
# [1071]	validation_0-logloss:0.04726
# [1072]	validation_0-logloss:0.04726
# [1073]	validation_0-logloss:0.04726
# [1074]	validation_0-logloss:0.04726
# [1075]	validation_0-logloss:0.04726
# [1076]	validation_0-logloss:0.04726
# [1077]	validation_0-logloss:0.04726
# [1078]	validation_0-logloss:0.04726
# [1079]	validation_0-logloss:0.04726
# [1080]	validation_0-logloss:0.04726
# [1081]	validation_0-logloss:0.04726
# [1082]	validation_0-logloss:0.04726
# [1083]	validation_0-logloss:0.04726
# [1084]	validation_0-logloss:0.04726
# [1085]	validation_0-logloss:0.04726
# [1086]	validation_0-logloss:0.04726
# [1087]	validation_0-logloss:0.04726
# [1088]	validation_0-logloss:0.04726
# [1089]	validation_0-logloss:0.04726
# [1090]	validation_0-logloss:0.04726
# [1091]	validation_0-logloss:0.04726
# [1092]	validation_0-logloss:0.04726
# [1093]	validation_0-logloss:0.04726
# [1094]	validation_0-logloss:0.04726
# [1095]	validation_0-logloss:0.04726
# [1096]	validation_0-logloss:0.04726
# [1097]	validation_0-logloss:0.04726
# [1098]	validation_0-logloss:0.04726
# [1099]	validation_0-logloss:0.04726
# [1100]	validation_0-logloss:0.04726
# [1101]	validation_0-logloss:0.04726
# [1102]	validation_0-logloss:0.04726
# [1103]	validation_0-logloss:0.04726
# [1104]	validation_0-logloss:0.04726
# [1105]	validation_0-logloss:0.04726
# [1106]	validation_0-logloss:0.04726
# [1107]	validation_0-logloss:0.04726
# [1108]	validation_0-logloss:0.04726
# [1109]	validation_0-logloss:0.04726
# [1110]	validation_0-logloss:0.04726
# [1111]	validation_0-logloss:0.04726
# [1112]	validation_0-logloss:0.04726
# [1113]	validation_0-logloss:0.04726
# [1114]	validation_0-logloss:0.04726
# [1115]	validation_0-logloss:0.04726
# [1116]	validation_0-logloss:0.04726
# [1117]	validation_0-logloss:0.04726
# [1118]	validation_0-logloss:0.04726
# [1119]	validation_0-logloss:0.04726
# [1120]	validation_0-logloss:0.04726
# [1121]	validation_0-logloss:0.04726
# [1122]	validation_0-logloss:0.04726
# [1123]	validation_0-logloss:0.04726
# [1124]	validation_0-logloss:0.04726
# [1125]	validation_0-logloss:0.04726
# [1126]	validation_0-logloss:0.04726
# [1127]	validation_0-logloss:0.04726
# [1128]	validation_0-logloss:0.04726
# [1129]	validation_0-logloss:0.04726
# [1130]	validation_0-logloss:0.04726
# [1131]	validation_0-logloss:0.04726
# [1132]	validation_0-logloss:0.04726
# [1133]	validation_0-logloss:0.04726
# [1134]	validation_0-logloss:0.04726
# [1135]	validation_0-logloss:0.04726
# [1136]	validation_0-logloss:0.04726
# [1137]	validation_0-logloss:0.04726
# [1138]	validation_0-logloss:0.04726
# [1139]	validation_0-logloss:0.04726
# [1140]	validation_0-logloss:0.04726
# [1141]	validation_0-logloss:0.04726
# [1142]	validation_0-logloss:0.04726
# [1143]	validation_0-logloss:0.04726
# [1144]	validation_0-logloss:0.04726
# [1145]	validation_0-logloss:0.04726
# [1146]	validation_0-logloss:0.04726
# [1147]	validation_0-logloss:0.04726
# [1148]	validation_0-logloss:0.04726
# [1149]	validation_0-logloss:0.04726
# [1150]	validation_0-logloss:0.04726
# [1151]	validation_0-logloss:0.04726
# [1152]	validation_0-logloss:0.04726
# [1153]	validation_0-logloss:0.04726
# [1154]	validation_0-logloss:0.04726
# [1155]	validation_0-logloss:0.04726
# [1156]	validation_0-logloss:0.04726
# [1157]	validation_0-logloss:0.04726
# [1158]	validation_0-logloss:0.04726
# [1159]	validation_0-logloss:0.04726
# [1160]	validation_0-logloss:0.04726
# [1161]	validation_0-logloss:0.04726
# [1162]	validation_0-logloss:0.04726
# [1163]	validation_0-logloss:0.04726
# [1164]	validation_0-logloss:0.04726
# [1165]	validation_0-logloss:0.04726
# [1166]	validation_0-logloss:0.04726
# [1167]	validation_0-logloss:0.04726
# [1168]	validation_0-logloss:0.04726
# [1169]	validation_0-logloss:0.04726
# [1170]	validation_0-logloss:0.04726
# [1171]	validation_0-logloss:0.04726
# [1172]	validation_0-logloss:0.04726
# [1173]	validation_0-logloss:0.04726
# [1174]	validation_0-logloss:0.04726
# [1175]	validation_0-logloss:0.04726
# [1176]	validation_0-logloss:0.04726
# [1177]	validation_0-logloss:0.04726
# [1178]	validation_0-logloss:0.04726
# [1179]	validation_0-logloss:0.04726
# [1180]	validation_0-logloss:0.04726
# [1181]	validation_0-logloss:0.04726
# [1182]	validation_0-logloss:0.04726
# [1183]	validation_0-logloss:0.04726
# [1184]	validation_0-logloss:0.04726
# [1185]	validation_0-logloss:0.04726
# [1186]	validation_0-logloss:0.04726
# [1187]	validation_0-logloss:0.04726
# [1188]	validation_0-logloss:0.04726
# [1189]	validation_0-logloss:0.04726
# [1190]	validation_0-logloss:0.04726
# [1191]	validation_0-logloss:0.04726
# [1192]	validation_0-logloss:0.04726
# [1193]	validation_0-logloss:0.04726
# [1194]	validation_0-logloss:0.04726
# [1195]	validation_0-logloss:0.04726
# [1196]	validation_0-logloss:0.04726
# [1197]	validation_0-logloss:0.04726
# [1198]	validation_0-logloss:0.04726
# [1199]	validation_0-logloss:0.04726
# [1200]	validation_0-logloss:0.04726
# [1201]	validation_0-logloss:0.04726
# [1202]	validation_0-logloss:0.04726
# [1203]	validation_0-logloss:0.04726
# [1204]	validation_0-logloss:0.04726
# [1205]	validation_0-logloss:0.04726
# [1206]	validation_0-logloss:0.04726
# [1207]	validation_0-logloss:0.04726
# [1208]	validation_0-logloss:0.04726
# [1209]	validation_0-logloss:0.04726
# [1210]	validation_0-logloss:0.04726
# [1211]	validation_0-logloss:0.04726
# [1212]	validation_0-logloss:0.04726
# [1213]	validation_0-logloss:0.04726
# [1214]	validation_0-logloss:0.04726
# [1215]	validation_0-logloss:0.04726
# [1216]	validation_0-logloss:0.04726
# [1217]	validation_0-logloss:0.04726
# [1218]	validation_0-logloss:0.04726
# [1219]	validation_0-logloss:0.04726
# [1220]	validation_0-logloss:0.04726
# [1221]	validation_0-logloss:0.04726
# [1222]	validation_0-logloss:0.04726
# [1223]	validation_0-logloss:0.04726
# [1224]	validation_0-logloss:0.04726
# [1225]	validation_0-logloss:0.04726
# [1226]	validation_0-logloss:0.04726
# [1227]	validation_0-logloss:0.04726
# [1228]	validation_0-logloss:0.04726
# [1229]	validation_0-logloss:0.04726
# [1230]	validation_0-logloss:0.04726
# [1231]	validation_0-logloss:0.04726
# [1232]	validation_0-logloss:0.04726
# [1233]	validation_0-logloss:0.04726
# [1234]	validation_0-logloss:0.04726
# [1235]	validation_0-logloss:0.04726
# [1236]	validation_0-logloss:0.04726
# [1237]	validation_0-logloss:0.04726
# [1238]	validation_0-logloss:0.04726
# [1239]	validation_0-logloss:0.04726
# [1240]	validation_0-logloss:0.04726
# [1241]	validation_0-logloss:0.04726
# [1242]	validation_0-logloss:0.04726
# [1243]	validation_0-logloss:0.04726
# [1244]	validation_0-logloss:0.04726
# [1245]	validation_0-logloss:0.04726
# [1246]	validation_0-logloss:0.04726
# [1247]	validation_0-logloss:0.04726
# [1248]	validation_0-logloss:0.04726
# [1249]	validation_0-logloss:0.04726
# [1250]	validation_0-logloss:0.04726
# [1251]	validation_0-logloss:0.04726
# [1252]	validation_0-logloss:0.04726
# [1253]	validation_0-logloss:0.04726
# [1254]	validation_0-logloss:0.04726
# [1255]	validation_0-logloss:0.04726
# [1256]	validation_0-logloss:0.04726
# [1257]	validation_0-logloss:0.04726
# [1258]	validation_0-logloss:0.04726
# [1259]	validation_0-logloss:0.04726
# [1260]	validation_0-logloss:0.04726
# [1261]	validation_0-logloss:0.04726
# [1262]	validation_0-logloss:0.04726
# [1263]	validation_0-logloss:0.04726
# [1264]	validation_0-logloss:0.04726
# [1265]	validation_0-logloss:0.04726
# [1266]	validation_0-logloss:0.04726
# [1267]	validation_0-logloss:0.04726
# [1268]	validation_0-logloss:0.04726
# [1269]	validation_0-logloss:0.04726
# [1270]	validation_0-logloss:0.04726
# [1271]	validation_0-logloss:0.04726
# [1272]	validation_0-logloss:0.04726
# [1273]	validation_0-logloss:0.04726
# [1274]	validation_0-logloss:0.04726
# Finished 3
# 355677 40130 35660

# %%
meta['fold'] = meta['fold'].astype(int)
meta.head()

# %%
meta = meta.groupby(
    ['Chrom', 'Strand', 'SeqEnum', 'Start', 'y_true', 'fold'],
    as_index=False
).agg(
    {
        'GeneID': lambda vs: ';'.join(vs),
        'TranscriptID': lambda vs: ';'.join(vs),
        'y_prob': 'mean'
    }
)

# %%
meta.to_csv(DATA_PATHS['cv'], index=False)

# %%
def unravel_scores(metadata, ts = 0.5, group_vs=['fold', 'Start']):
    for g, gg in metadata.groupby(group_vs):
        y_pred = np.zeros(len(gg), dtype=int)
        y_pred[gg['y_prob'] >= ts] = 1
        # print(g, gg, y_pred, sep='\n')
        num_pos = gg['y_true'].sum()
        num_neg = len(gg) - num_pos
        s = compute_scores(y_pred, gg['y_true'].values)
        if not isinstance(g, tuple):
            g = (g, )
        yield *g, len(gg), num_pos, num_neg, *iter(s.values())

# %%
scores_cv = pd.DataFrame(
    unravel_scores(meta),
    columns=['Fold', 'Start', 'Size', 'NumPos',
             'NumNeg', 'F1', 'PRC', 'REC', 'BAC'])

# %%
scores_cv_agg = scores_cv[
    scores_cv.NumPos != 0
].groupby(
    ['Start']
).agg(
    {'Size': 'sum', 'NumPos': 'sum', 'NumNeg': 'sum',
     'F1': 'mean', 'PRC': 'mean', 'REC': 'mean'}
)

# %%
scores_cv.to_csv(DATA / 'cv_scores.csv', index=False)
scores_cv_agg.to_csv(DATA / 'cv_scores_agg.csv')

# %% [markdown]
# ## Retrain and save model

# %%
best_params = {
    'grow_policy': 'lossguide',
    'learning_rate': 0.09936924483593312,
    'max_depth': 8,
    'gamma': 1.477343705723823,
    'reg_lambda': 2.2045941577676516,
    'reg_alpha': 17.903008925728273,
    'colsample_bytree': 0.5943715796308908,
    'colsample_bylevel': 0.7329001180439547,
    'scale_pos_weight': 10.655241464899479,
    'n_estimators': 10000,
    'tree_method': 'gpu_hist',
    'early_stopping_rounds': 10,
    'gpu_id': '1'
}

# %%
train_x = pd.read_csv(DATA_PATHS['train_x'])
train_y = pd.read_csv(DATA_PATHS['train_y'])
val_x = pd.read_csv(DATA_PATHS['val_x'])
val_y = pd.read_csv(DATA_PATHS['val_y'])
test_x = pd.read_csv(DATA_PATHS['test_x'])
test_y = pd.read_csv(DATA_PATHS['test_y'])

# %%
len(train_x) + len(val_x) + len(test_x)
# Out:
# 437970

# %%
classifier = XGBClassifier(**best_params)
classifier.fit(train_x, train_y, eval_set=[(val_x, val_y)])

# %%
joblib.dump(classifier, DATA / 'XGBoost_model.joblib')

# %% [markdown]
# ## Predict 5'UTRs

# %%
def load_chunks(size):
    
    chunks = (
        pd.read_csv(DATA_PATHS[n], chunksize=size) for n in 
        ['rna_cell', 'signal', 'seq_rna', 'labels', 'meta'])
    
    for i, (cell_chunk, signal_chunk, seq_chunk, ys_chunk, meta_chunk) in enumerate(zip(*chunks), start=1):
        ds_x = pd.concat([signal_chunk, seq_chunk, cell_chunk], axis=1)
        meta_chunk['y_true'] = ys_chunk['Classes'].values
        yield ds_x, meta_chunk
        
def calc_pred_scores(df, threshold=0.5):
    y_prob = df['y_prob'].values
    y_pred = (df['y_prob'].values > threshold).astype(int)
    y_true = df['y_true'].values
    fn, fp, tn, tp = map(
        lambda x: len(df[df.PredictionType == x]), 
        ['FN', 'FP', 'TN', 'TP'])
    return {
        'f1': f1_score(y_true, y_pred, zero_division=0), 
        'prc': precision_score(y_true, y_pred, zero_division=0), 
        'rec': recall_score(y_true, y_pred, zero_division=0),
        'bac': balanced_accuracy_score(y_true, y_pred),
        'roc_auc': roc_auc_score(y_true, y_prob),
        'FN': fn, 'FP': fp, 'TN': tn, 'TP': tp,
    }

def annotate_predictions(df):
    df = df.copy()
    df.loc[(df.y_true == 1) & (df.y_pred == 1), 'PredictionType'] = 'TP'
    df.loc[(df.y_true == 1) & (df.y_pred == 0), 'PredictionType'] = 'FN'
    df.loc[(df.y_true == 0) & (df.y_pred == 1), 'PredictionType'] = 'FP'
    df.loc[(df.y_true == 0) & (df.y_pred == 0), 'PredictionType'] = 'TN'
    return df

def score(df, threshold):
    df = df.copy()
    df['y_true'] = df['y_true'].astype(int)
    scores = {
        codon: calc_pred_scores(group, threshold) 
        for codon, group in df.groupby('Start')}
    scores['All'] = calc_pred_scores(df, threshold)
    return scores

def agg_y_true(vs):
    if len(vs) == 1:
        return vs
    s = set(vs)
    if len(s) > 1:
        return ';'.join(map(str, vs))
    return s.pop()

def unravel_scores(scores):
    for ds_name, ds_vs in scores.items():
        for codon_name, codon_scores in ds_vs.items():
            for score_name, score_val in codon_scores.items():
                yield ds_name, codon_name, score_name, score_val
                
def get_color(y_pred, y_true, dataset):
    green, blue, red, black = (
        '0,255,0', '0,0,255', '255,0,0', '0,0,0')
    if dataset == 'Inference':
        if y_pred == 1:
            return green
        return blue
    if y_pred == 1 and y_true == 1:
        return green
    if y_pred == 0 and y_true == 0:
        return blue
    if y_pred == 0 and y_true == 1:
        return red
    return black
                
def wrap_row(row):
    label = row.Dataset
    color = get_color(row.y_pred, row.y_true, row.Dataset)
    start = row.SeqEnum if row.Strand == '+' else row.SeqEnum - 2
    end = start + 3
    return (f'{row.Chrom} {start} {end} {label} '
            f'{int(row.y_prob * 100)} {row.Strand} {start} {end} {color}')

def pred2bed(df, out_path):
    with open(out_path, 'w') as f:
        print('track name="XGBboost predictions v4.7" '
              'itemRgb="On"', file=f)
        for _, row in tqdm(df.iterrows()):
            print(wrap_row(row), file=f)

# %%
# classifier = joblib.load(DATA / 'XGBoost_model.joblib')

# %%
results = []
chunks_iter = load_chunks(100000)
for ds_x, meta in tqdm(chunks_iter):
    y_prob = classifier.predict_proba(ds_x)[:, 1]
    meta['y_prob'] = y_prob
    results.append(meta)

# %%
df_pred = pd.concat(results)

# %%
df_pred.loc[df_pred.Dataset.isna(), 'Dataset'] = 'Inference'

# %%
df_pred.loc[df_pred.Dataset == 'Inference', 'y_true'] = -1

# %%
df_pred = df_pred.groupby(
        ['Chrom', 'Strand', 'Start', 'SeqEnum', 'Dataset'], 
        as_index=False
    ).agg(
    {
        'GeneID':  lambda vs: ';'.join(sorted(set(vs))),
        'TranscriptID': lambda vs: ';'.join(sorted(set(vs))),
        'y_true': agg_y_true,
        'y_prob': 'mean',
})

# %%
df_pred['y_pred'] = (df_pred['y_prob'] > 0.5).astype(int)

# %%
df_pred = annotate_predictions(df_pred)

# %%
df_pred.shape

# %%
df_pred.y_true.value_counts()

# %%
scores = {ds_name: score(df_pred[(df_pred.Dataset == ds_name)], 0.5) for ds_name in ('Train', 'Val', 'Test')}

# %%
df_scores = pd.DataFrame(
    unravel_scores(scores), 
    columns=['Dataset', 'Codon', 'ScoreType', 'ScoreVal']
).round(2).pivot(
    index=['Dataset', 'Codon'], columns='ScoreType', values='ScoreVal'
)

for c in ['FN', 'FP', 'TN', 'TP']:
    df_scores[c] = df_scores[c].astype(int)

df_scores['P'] = df_scores['TP'] + df_scores['FN']

df_scores = df_scores.reset_index().sort_values(
    ['Dataset', 'P'], ascending=[True, False]
).set_index(['Dataset', 'Codon'])[[
    'f1', 'prc', 'rec', 'bac', 'TN', 'FN', 'FP', 'TP', 'P'
]]

df_scores
# Out:
# ScoreType        f1   prc   rec   bac      TN   FN    FP    TP     P
# Dataset Codon
# Test    All    0.71  0.66  0.77  0.88   30037  133   235   451   584
#         CTG    0.73  0.67  0.79  0.89    5600   40    75   154   194
#         ATG    0.76  0.70  0.82  0.89    1887   31    59   139   170
#         GTG    0.66  0.61  0.72  0.85    3759   24    39    61    85
#         ACG    0.69  0.65  0.73  0.86    1400   12    17    32    44
#         TTG    0.66  0.62  0.70  0.85    3042   13    19    31    44
#         ATC    0.80  0.80  0.80  0.90    1918    5     5    20    25
#         ATT    0.55  0.44  0.73  0.86    2347    4    14    11    15
#         ATA    0.55  0.43  0.75  0.87    1307    1     4     3     4
#         AAG    0.00  0.00  0.00  0.50    3762    2     1     0     2
#         AGG    0.00  0.00  0.00  0.50    5015    1     2     0     1
# Train   All    0.89  0.80  1.00  1.00  254850    0  1079  4273  4273
#         CTG    0.89  0.80  1.00  1.00   47752    0   362  1437  1437
#         ATG    0.88  0.78  1.00  0.99   16422    0   390  1397  1397
#         GTG    0.89  0.80  1.00  1.00   31360    0   143   577   577
#         ACG    0.91  0.83  1.00  1.00   11394    0    55   268   268
#         TTG    0.89  0.80  1.00  1.00   25369    0    64   254   254
#         ATC    0.93  0.88  1.00  1.00   16686    0    18   128   128
#         ATT    0.89  0.81  1.00  1.00   19633    0    30   127   127
#         ATA    0.86  0.75  1.00  1.00   11725    0    13    40    40
#         AGG    0.94  0.89  1.00  1.00   42684    0     4    31    31
#         AAG    1.00  1.00  1.00  1.00   31825    0     0    14    14
# Val     All    0.65  0.59  0.72  0.86   29581  153   274   395   548
#         ATG    0.71  0.64  0.80  0.87    1844   41    91   159   200
#         CTG    0.65  0.57  0.76  0.87    5355   38    90   118   156
#         GTG    0.59  0.52  0.67  0.83    3493   21    40    43    64
#         ACG    0.60  0.60  0.60  0.79    1330   14    14    21    35
#         TTG    0.62  0.52  0.77  0.88    2846    7    22    24    31
#         ATC    0.54  0.69  0.44  0.72    1890   14     5    11    25
#         ATT    0.65  0.65  0.65  0.82    2399    8     8    15    23
#         ATA    0.46  0.50  0.43  0.71    1338    4     3     3     7
#         AGG    0.25  0.50  0.17  0.58    5026    5     1     1     6
#         AAG    0.00  0.00  0.00  0.50    4060    1     0     0     1

# %%
df_pred.to_csv(DATA / 'predictions_5UTR_v4.7.csv', index=False)

# %%
df_scores.to_csv(DATA / 'prediction_scores_v4.7.tsv', sep='\t')

# %%
pred2bed(df_pred, DATA / 'predictions_5UTR_v4.7.bed')
# Out:
# 0it [00:00, ?it/s]

# %%
print(df_scores.to_latex())
# Out:
# \begin{tabular}{llrrrrrrrrr}
# \toprule
#     & ScoreType &    f1 &   prc &   rec &   bac &      TN &   FN &    FP &    TP &     P \\
# Dataset & Codon &       &       &       &       &         &      &       &       &       \\
# \midrule
# Test & All &  0.71 &  0.66 &  0.77 &  0.88 &   30037 &  133 &   235 &   451 &   584 \\
#     & CTG &  0.73 &  0.67 &  0.79 &  0.89 &    5600 &   40 &    75 &   154 &   194 \\
#     & ATG &  0.76 &  0.70 &  0.82 &  0.89 &    1887 &   31 &    59 &   139 &   170 \\
#     & GTG &  0.66 &  0.61 &  0.72 &  0.85 &    3759 &   24 &    39 &    61 &    85 \\
#     & ACG &  0.69 &  0.65 &  0.73 &  0.86 &    1400 &   12 &    17 &    32 &    44 \\
